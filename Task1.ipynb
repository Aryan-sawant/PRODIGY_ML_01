# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-f40d00bb-530e-4db0-9f8b-ff6d15f05316" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f40d00bb-530e-4db0-9f8b-ff6d15f05316">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv('data.csv')

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
# Required Independent Variables
x=data[['bedrooms','bathrooms','sqft_living']]
print(x)
# Out:
#       bedrooms  bathrooms  sqft_living
# 0          3.0       1.50         1340
# 1          5.0       2.50         3650
# 2          3.0       2.00         1930
# 3          3.0       2.25         2000
# 4          4.0       2.50         1940
# ...        ...        ...          ...
# 4595       3.0       1.75         1510
# 4596       3.0       2.50         1460
# 4597       3.0       2.50         3010
# 4598       4.0       2.00         2090
# 4599       3.0       2.50         1490
#
# [4600 rows x 3 columns]

# %%
# Required Dependent Variable
y=data[['price']]
print(y)
# Out:
#              price
# 0     3.130000e+05
# 1     2.384000e+06
# 2     3.420000e+05
# 3     4.200000e+05
# 4     5.500000e+05
# ...            ...
# 4595  3.081667e+05
# 4596  5.343333e+05
# 4597  4.169042e+05
# 4598  2.034000e+05
# 4599  2.206000e+05
#
# [4600 rows x 1 columns]

# %%
#Training and Testing the model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#Splitting the data into 70% training and 30% testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [[ 556343.62924276]
#  [ 656685.82104669]
#  [ 253267.11149804]
#  ...
#  [1106283.13637776]
#  [ 336076.93183746]
#  [ 356443.28713407]]

# %%
#Claculating mse,r2,rmse and mae
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
import numpy as np

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
print(f"Root Mean Square Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 571611902829.7235
# R-squared: 0.08758385117742251
# Root Mean Square Error: 756050.1986176074
# Mean Absolute Error: 194750.75278590832

# %%
#Uploading new file to predict new house prices
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-9494fdb1-6cd9-46ec-b961-3e217cc40b77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9494fdb1-6cd9-46ec-b961-3e217cc40b77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
new_house=pd.read_csv("output.csv")
#Independent Variables of new file
x_new=new_house[['bedrooms','bathrooms','sqft_living']]
print(x_new)
# Out:
#       bedrooms  bathrooms  sqft_living
# 0          3.0       1.50         1340
# 1          5.0       2.50         3650
# 2          3.0       2.00         1930
# 3          3.0       2.25         2000
# 4          4.0       2.50         1940
# ...        ...        ...          ...
# 4595       3.0       1.75         1510
# 4596       3.0       2.50         1460
# 4597       3.0       2.50         3010
# 4598       4.0       2.00         2090
# 4599       3.0       2.50         1490
#
# [4600 rows x 3 columns]

# %%
#Dependent Variable of new file
y_new=new_house[["price"]]
print(y_new)
# Out:
#              price
# 0     3.130000e+05
# 1     2.384000e+06
# 2     3.420000e+05
# 3     4.200000e+05
# 4     5.500000e+05
# ...            ...
# 4595  3.081667e+05
# 4596  5.343333e+05
# 4597  4.169042e+05
# 4598  2.034000e+05
# 4599  2.206000e+05
#
# [4600 rows x 1 columns]

# %%
predicted= model.predict(x_new)
predicted_price=pd.DataFrame(predicted)
print(f'Predicted Price for the new houses in USD($):\n{predicted_price}')
# Out:
# Predicted Price for the new houses in USD($):
#                   0
# 0     339770.385938
# 1     887391.269128
# 2     508987.659981
# 3     529831.660780
# 4     458306.952799
# ...             ...
# 4595  388954.225058
# 4596  377802.647820
# 4597  817070.141797
# 4598  498804.482332
# 4599  386304.599316
#
# [4600 rows x 1 columns]
